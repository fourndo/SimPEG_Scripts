# %%
import numpy as np
import matplotlib.pyplot as plt
from SimPEG import Utils
from scipy.constants import G
import time

# %%
X, Y = np.meshgrid(np.arange(-10.1,11,0.5), np.arange(-10.1,11,0.5))
Z = np.ones_like(X) * 10

x, y, z = X.reshape(-1), Y.reshape(-1), Z.reshape(-1)

# %%
np.abs(r).min()
# Out:
# 14.935862880998874

# %%
# Define sphere at origin
R = 1 # meters
xc, yc, zc = 0, 0, 0
rho = 1.

unit_conv = 1e+8  # Unit conversion from SI to (mgal*g/cc)
dx = (x - xc)
dy = (y - yc)
dz = (z - zc)

rvec = np.c_[dx, dy, dz]
r = np.sqrt((dx)**2 + (dy)**2 + (dz)**2)

# Define gravity fields from the source
M = R**3. * 4. / 3. * np.pi * rho

g = -G * (1. / r**3) * M * unit_conv

gx_ana = g * dx
gy_ana = g * dy
gz_ana = g * dz

# %%
plt.figure(figsize=(12,8))
axs = plt.subplot(1,3,1)
plt.contourf(X, Y, gx_ana.reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gx")
axs = plt.subplot(1,3,2)
plt.contourf(X, Y, gy_ana.reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gy")
axs = plt.subplot(1,3,3)
plt.contourf(X, Y, gz_ana.reshape(X.shape))

axs.set_aspect('equal')
axs.set_title("gz")
# Out:
# Text(0.5, 1.0, 'gz')

# %%
gxx_ana = -(
    1/r**3 - 3*dx**2./r**5
)

gxy_ana = -(
    -3*dx*dy/r**5
)

gxz_ana = -(
    -3*dx*dz/r**5
)

gyy_ana = -(
    1/r**3 - 3*dy**2./r**5
)

gyx_ana = -(
    -3*dy*dx/r**5
)

gyz_ana = -(
    -3*dy*dz/r**5
)

gzz_ana = -(
    1/r**3 - 3*dz**2./r**5
)

gzx_ana = -(
    -3*dz*dx/r**5
)

gzy_ana = -(
    -3*dy*dz/r**5
)

# %%
plt.figure(figsize=(12,12))

axs = plt.subplot(3,3,1)
plt.contourf(X, Y, gxx_ana.reshape(X.shape))
axs.set_aspect('equal')

axs = plt.subplot(3,3,2)
plt.contourf(X, Y, gxy_ana.reshape(X.shape))
axs.set_aspect('equal')

axs = plt.subplot(3,3,3)
plt.contourf(X, Y, gxz_ana.reshape(X.shape))
axs.set_aspect('equal')

axs = plt.subplot(3,3,5)
plt.contourf(X, Y, gyy_ana.reshape(X.shape))

axs = plt.subplot(3,3,6)
plt.contourf(X, Y, gyz_ana.reshape(X.shape))

axs = plt.subplot(3,3,9)
plt.contourf(X, Y, gzz_ana.reshape(X.shape))

axs.set_aspect('equal')

# %%
from SimPEG.Utils import mkvc
import scipy.constants as constants
NewtG = constants.G*1e+8

# %%
dz
# Out:
# array([3.1, 3.1, 3.1, ..., 3.1, 3.1, 3.1])

# %%
# Compute it with integral
Xn = np.c_[-0.5, 0.5]
Yn = np.c_[-0.5, 0.5]
Zn = np.c_[-0.5, 0.5]


row = np.zeros((1, Xn.shape[0]))

# Compute contribution from each corners
tx = np.zeros((x.shape[0], Xn.shape[0]))
ty = np.zeros((x.shape[0], Xn.shape[0]))
tz = np.zeros((x.shape[0], Xn.shape[0]))

txx = np.zeros((x.shape[0], Xn.shape[0]))
txy = np.zeros((x.shape[0], Xn.shape[0]))
tyy = np.zeros((x.shape[0], Xn.shape[0]))
txz = np.zeros((x.shape[0], Xn.shape[0]))
tyz = np.zeros((x.shape[0], Xn.shape[0]))
eps= 1e-16

start = time.time()

for ii in range(x.shape[0]):
    dz = Zn - z[ii]

    dy = Yn - y[ii]

    dx = Xn - x[ii]


    for aa in range(2):
        for bb in range(2):
            for cc in range(2):

                r = (
                        mkvc(dx[:, aa]) ** 2 +
                        mkvc(dy[:, bb]) ** 2 +
                        mkvc(dz[:, cc]) ** 2
                    ) ** (0.50) + eps


                tx[ii,:] += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dy[:, bb] * np.log(dz[:, cc] + r + eps) +
                    dz[:, cc] * np.log(dy[:, bb] + r + eps) -
                    dx[:, aa] * np.arctan(dy[:, bb] * dz[:, cc] /
                                          (dx[:, aa] * r + eps)))


                ty[ii,:]  += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dx[:, aa] * np.log(dz[:, cc] + r + eps) +
                    dz[:, cc] * np.log(dx[:, aa] + r + eps) -
                    dy[:, bb] * np.arctan(dx[:, aa] * dz[:, cc] /
                                          (dy[:, bb] * r + eps)))


                tz[ii,:]  += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dx[:, aa] * np.log(dy[:, bb] + r + eps) +
                    dy[:, bb] * np.log(dx[:, aa] + r + eps) -
                    dz[:, cc] * np.arctan(dx[:, aa] * dy[:, bb] /
                                          (dz[:, cc] * r + eps)))
                
                arg = dy[:, bb]*dz[:, cc]/( dx[:, aa]*r + eps)
                
                txx[ii,:] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dx[:, aa] * dy[:, bb] / (r*(dz[:, cc] + r)+ eps) + 
                    dx[:, aa] * dz[:, cc] / (r*(dy[:, bb] + r)+ eps) - 
                    np.arctan(arg+eps) +
                    dx[:, aa] * (1./ (1+arg**2.)) * 
                    dy[:, bb]*dz[:, cc]/(dx[:, aa]*r+ eps)**2. * 
                    (r + dx[:, aa]**2./(r+ eps)) 
                )
                
          
                txy[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dz[:, cc] + r) + dy[:, bb]**2./ (r*(dz[:, cc] + r)) +
                    dz[:, cc] / (r+eps)  - 
                    1. / (1+arg**2.+ eps) * (dz[:, cc]/r**2) * (r - dy[:, bb]**2./r)
                    
                )
            
                txz[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dy[:, bb] + r) + dz[:, cc]**2./ (r*(dy[:, bb] + r)) +
                    dy[:, bb] / r  - 
                    1. / (1+arg**2.) * (dy[:, bb]/(r**2)) * (r - dz[:, cc]**2./r)
                    
                )
                
                arg = dx[:, aa]*dz[:, cc]/( dy[:, bb]*r + eps)
                
                tyy[ii,:] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dy[:, bb] * dx[:, aa] / (r*(dz[:, cc] + r)+ eps) + 
                    dy[:, bb] * dz[:, cc] / (r*(dx[:, aa] + r)+ eps) - 
                    np.arctan(arg+eps) +
                    dy[:, bb] * (1./ (1+arg**2.+ eps)) * 
                    dx[:, aa]*dz[:, cc]/(dy[:, bb]*r+ eps)**2. * 
                    (r + dy[:, bb]**2./(r+ eps)) 
                )
                
                tyz[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dx[:, aa] + r) + dz[:, cc]**2./ (r*(dx[:, aa] + r)) +
                    dx[:, aa] / r  - 
                    1. / (1+arg**2.) * (dx[:, aa]/(r**2)) * (r - dz[:, cc]**2./r)
                    
                )


print("Run in %f" % (time.time() - start))
# Out:
# Run in 3.928004

# %%
row = np.zeros((1, Xn.shape[0]))

# Compute contribution from each corners
tx = np.zeros((x.shape[0], Xn.shape[0]))
ty = np.zeros((x.shape[0], Xn.shape[0]))
tz = np.zeros((x.shape[0], Xn.shape[0]))

txx = np.zeros((x.shape[0], Xn.shape[0]))
txy = np.zeros((x.shape[0], Xn.shape[0]))
tyy = np.zeros((x.shape[0], Xn.shape[0]))
txz = np.zeros((x.shape[0], Xn.shape[0]))
tyz = np.zeros((x.shape[0], Xn.shape[0]))
eps= 1e-16

start = time.time()

for ii in range(x.shape[0]):
    dz = Zn - z[ii]

    dy = Yn - y[ii]

    dx = Xn - x[ii]


    for aa in range(2):
        for bb in range(2):
            for cc in range(2):

                r = (
                        mkvc(dx[:, aa]) ** 2 +
                        mkvc(dy[:, bb]) ** 2 +
                        mkvc(dz[:, cc]) ** 2
                    ) ** (0.50) + eps

                dz_r = dz[:, cc] + r + eps
                dy_r = dy[:, bb] + r + eps
                dx_r = dx[:, aa] + r + eps
                
                dxr = dx[:, aa] * r + eps
                dyr = dy[:, bb] * r + eps
                dzr = dz[:, cc] * r + eps
                
                dydz = dy[:, bb] * dz[:, cc]
                dxdy = dx[:, aa] * dy[:, bb]
                dxdz = dx[:, aa] * dz[:, cc]

                tx[ii,:] += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dy[:, bb] * np.log(dz_r) +
                    dz[:, cc] * np.log(dy_r) -
                    dx[:, aa] * np.arctan(dydz /
                                          dxr)
                )


                ty[ii,:]  += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dx[:, aa] * np.log(dz_r) +
                    dz[:, cc] * np.log(dx_r) -
                    dy[:, bb] * np.arctan(dxdz /
                                          dyr)
                )


                tz[ii,:]  += NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dx[:, aa] * np.log(dy_r) +
                    dy[:, bb] * np.log(dx_r) -
                    dz[:, cc] * np.arctan(dxdy /
                                          dzr)
                )
                
                arg = dy[:, bb] * dz[:, cc] / dxr
                
                txx[ii,:] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dxdy / (r * dz_r + eps) + 
                    dxdz / (r * dy_r + eps) - 
                    np.arctan(arg+eps) +
                    dx[:, aa] * (1./ (1+arg**2.)) * 
                    dydz/dxr**2. * 
                    (r + dx[:, aa]**2./r) 
                )
                
          
                txy[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dz_r) + dy[:, bb]**2./ (r*dz_r) +
                    dz[:, cc] / r  - 
                    1. / (1+arg**2.+ eps) * (dz[:, cc]/r**2) * (r - dy[:, bb]**2./r)
                    
                )
            
                txz[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dy_r) + dz[:, cc]**2./ (r*dy_r) +
                    dy[:, bb] / r  - 
                    1. / (1+arg**2.) * (dy[:, bb]/(r**2)) * (r - dz[:, cc]**2./r)
                    
                )
                
                arg = dx[:, aa]*dz[:, cc]/dyr
                
                tyy[ii,:] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    dxdy / (r*dz_r+ eps) + 
                    dydz / (r*dx_r+ eps) - 
                    np.arctan(arg+eps) +
                    dy[:, bb] * (1./ (1+arg**2.+ eps)) * 
                    dxdz/dyr**2. * 
                    (r + dy[:, bb]**2./r) 
                )
                
                tyz[ii, :] -= NewtG * (-1) ** aa * (-1) ** bb * (-1) ** cc * (
                    np.log(dx_r) + dz[:, cc]**2./ (r*(dx_r)) +
                    dx[:, aa] / r  - 
                    1. / (1+arg**2.) * (dx[:, aa]/(r**2)) * (r - dz[:, cc]**2./r)
                    
                )

print("Run in %f" % (time.time() - start))
# Out:
# Run in 3.322130

# %%
# Try to run with MAG kernel
# Out:
# -1

# %%
# Volume scaling 
Vratio = (4./3.*np.pi*R**3.) / 1

gx = np.dot(tx, rho*Vratio)
gy = np.dot(ty, rho*Vratio)
gz = np.dot(tz, rho*Vratio)
gxx = np.dot(txx, rho*Vratio)
gxy = np.dot(txy, rho*Vratio)
gxz = np.dot(txz, rho*Vratio)
gyy = np.dot(tyy, rho*Vratio)
gyz = np.dot(tyz, rho*Vratio)

gzz = -gxx-gyy

# %%
plt.figure(figsize=(12,8))
axs = plt.subplot(1,3,1)
plt.contourf(X, Y, np.dot(gx, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gx")
axs = plt.subplot(1,3,2)
plt.contourf(X, Y, np.dot(gy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gy")
axs = plt.subplot(1,3,3)
plt.contourf(X, Y, np.dot(gz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gz")


plt.figure(figsize=(12,12))

axs = plt.subplot(3,3,1)
plt.contourf(X, Y, np.dot(gxx, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxx")

axs = plt.subplot(3,3,2)
plt.contourf(X, Y, np.dot(gxy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxy")

axs = plt.subplot(3,3,3)
plt.contourf(X, Y, np.dot(gxz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxz")

axs = plt.subplot(3,3,5)
plt.contourf(X, Y, np.dot(gyy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gyy")

axs = plt.subplot(3,3,6)
plt.contourf(X, Y, np.dot(gyz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gyz")

axs = plt.subplot(3,3,9)
plt.contourf(X, Y, np.dot(gzz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gzz")
# Out:
# Text(0.5, 1.0, 'gzz')

# %%
plt.figure(figsize=(12,8))
axs = plt.subplot(1,3,1)
plt.contourf(X, Y, np.dot(gx_ana, 1).reshape(X.shape) - np.dot(gx, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gx")
axs = plt.subplot(1,3,2)
plt.contourf(X, Y, np.dot(gy_ana, 1).reshape(X.shape) - np.dot(gy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gy")
axs = plt.subplot(1,3,3)
plt.contourf(X, Y, np.dot(gz_ana, 1).reshape(X.shape) - np.dot(gz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gz")


plt.figure(figsize=(12,12))

axs = plt.subplot(3,3,1)
plt.contourf(X, Y, np.dot(gx_ana, 1).reshape(X.shape) - np.dot(gxx, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxx")

axs = plt.subplot(3,3,2)
plt.contourf(X, Y, np.dot(gxy_ana, 1).reshape(X.shape) - np.dot(gxy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxy")

axs = plt.subplot(3,3,3)
plt.contourf(X, Y, np.dot(gxz_ana, 1).reshape(X.shape) - np.dot(gxz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gxz")

axs = plt.subplot(3,3,5)
plt.contourf(X, Y, np.dot(gyy_ana, 1).reshape(X.shape) - np.dot(gyy, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gyy")

axs = plt.subplot(3,3,6)
plt.contourf(X, Y, np.dot(gyz_ana, 1).reshape(X.shape) - np.dot(gyz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gyz")

axs = plt.subplot(3,3,9)
plt.contourf(X, Y, np.dot(gzz_ana, 1).reshape(X.shape) - np.dot(gzz, 1).reshape(X.shape))
axs.set_aspect('equal')
axs.set_title("gzz")
# Out:
# Text(0.5, 1.0, 'gzz')
