# %%
# %matplotlib notebook
import numpy as np
import scipy as sp
import unittest
from discretize.utils import meshutils
import inspect
import matplotlib.pyplot as plt
from scipy.interpolate import griddata, LinearNDInterpolator
from SimPEG.Utils import mkvc
from scipy.spatial import cKDTree
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from scipy.spatial import Delaunay
import vtki

# %% [markdown]
# In this example, we demonstrate different mesh refinement strategies available for TreeMesh under the Utils.
# First let's define a simple ground survey and topography.

# %%
# Define a simple Gaussian topography
[xx, yy] = np.meshgrid(np.linspace(-200,200,20), np.linspace(-200,200,20))
b = 100
A = 50
zz = A*np.exp(-0.5*((xx/b)**2. + (yy/b)**2.))

topo = np.c_[xx.reshape(-1), yy.reshape(-1), zz.reshape(-1)]

print(topo.shape)

# %%
grid = vtki.PolyData(topo)
trian = grid.delauney_2d()

plotter = vtki.BackgroundPlotter(notebook=True)
plotter.add_mesh(trian)

# %%
# plot each face with a different color
# surf.plot(scalars=np.arange(3))
# Let's take a look at this topography


# # Create lines of observation points
# xr = np.linspace(-100., 100., 5)
# yr = np.linspace(-100., 100., 10)
# X, Y = np.meshgrid(xr, yr)
# xyz = np.c_[X.reshape(-1), Y.reshape(-1)]

# # Rotate at 45d for fun factor
# theta = np.radians(30)
# c, s = np.cos(theta), np.sin(theta)
# R = np.array(((c,-s), (s, c)))
# xyz = np.dot(R, xyz.T).T

# # Drape the lines to our topography
# F = LinearNDInterpolator(topo[:, :2], topo[:, 2])
# xyz = np.c_[xyz, F(xyz) + 1.]

# %%
tri = sp.spatial.Delaunay(topo)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot_trisurf(topo[:,0], topo[:,1], topo[:,2], triangles=tri.simplices, cmap=plt.cm.Spectral)
ax.scatter3D(xyz[:,0],xyz[:,1],xyz[:,2], s=30, c='k')
# ax.set_aspect()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Refine with point

# %%
# Create a mesh based on data extent
mesh = meshutils.meshBuilderXYZ(
    topo, [5, 5, 5],
    padX=[0, 0], padY=[0, 0], padZ=[0, 0],
    baseMesh=None,
    expFact=1.3,
    meshType='TREE',
    verticalAlignment='center'
)

mesh = meshutils.refineTreeXYZ(mesh, xyz, octreeLevels=[0,2,3], method='radial', finalize=True)
im = mesh.plotSlice(np.log10(mesh.vol), normal='Y', ind=63, grid=True, pcolorOpts={"cmap":"plasma"})
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Refine on triangulated surface from points

# %%
# Create a mesh based on data extent
mesh = meshutils.meshBuilderXYZ(
    topo, [5, 5, 5],
    padX=[0, 0], padY=[0, 0], padZ=[0, 0],
    baseMesh=None,
    expFact=1.3,
    meshType='TREE',
    verticalAlignment='center'
)

mesh = meshutils.refineTreeXYZ(mesh, xyz, octreeLevels=[2,2,3,0], octreeLevels_XY=[2,2,3,5], method='surface', finalize=True)
im = mesh.plotSlice(np.log10(mesh.vol), normal='Y', ind=63, grid=True, pcolorOpts={"cmap":"plasma"})
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Refine inside box

# %%
# Create a mesh based on data extent
mesh = meshutils.meshBuilderXYZ(
    topo, [5, 5, 5],
    padX=[0, 0], padY=[0, 0], padZ=[0, 0],
    baseMesh=None,
    expFact=1.3,
    meshType='TREE',
    verticalAlignment='center'
)


mesh = meshutils.refineTreeXYZ(mesh, xyz, octreeLevels=[2,5,3], method='box', finalize=True)
im = mesh.plotSlice(np.log10(mesh.vol), normal='Y', ind=63, grid=True, pcolorOpts={"cmap":"plasma"})
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Combine refines

# %%
# Create a mesh based on data extent
mesh = meshutils.meshBuilderXYZ(
    topo, [5, 5, 5],
    padX=[0, 0], padY=[0, 0], padZ=[0, 0],
    baseMesh=None,
    expFact=1.3,
    meshType='TREE',
    verticalAlignment='center'
)

mesh = meshutils.refineTreeXYZ(mesh, topo, octreeLevels=[0,2], method='surface', finalize=False)
mesh = meshutils.refineTreeXYZ(mesh, xyz, octreeLevels=[4,0], method='radial', finalize=True)


im = mesh.plotSlice(np.log10(mesh.vol), normal='Y', ind=63, grid=True, pcolorOpts={"cmap":"plasma"})
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# h = np.ones(64)*5
# mesh = Mesh.TreeMesh([h,h,h], )
# mesh.x0 = [-100.,-100.,-50.]
# mesh.refine(2, finalize=False)
# # mesh.insert_cells(xLoc, [3]*xLoc.shape[0], finalize=False)
# xLoc = np.vstack([[0.,100.,53.], [100.,100.,56.], [50.,25.,55.], [0.,-10.,52.]])


# expFactor = 2.

# centroid = np.kron(np.ones((xLoc.shape[0], 1)), np.mean(xLoc, axis=0))
# xLoc = (xLoc - centroid)*expFactor + centroid

# tri2D = Delaunay(xLoc[:,:2])

# # Compute normals
# # normal = [np.cross(xLoc[tri[1]]-xLoc[tri[0]], xLoc[tri[2]]-xLoc[tri[0]]) for tri in tri2D.simplices]
# # uNormal = [nn/np.linalg.norm(nn) for nn in normal]
# # d = [nn.dot(xLoc[tri[1]]) for abc, xyz in zip(uNormal, tri2D.simplices)]

# ax2=plt.subplot()
# plt.triplot(xLoc[:,0], xLoc[:,1], delTria.simplices.copy())

# plt.plot(xLoc[:,0], xLoc[:,1], 'o')

# nCpad = [2, 2, 2]

# maxRadius = 40
# maxDepth = 50

# maxLevel = 5

# # Convert nCpad to total distance
# rMax = np.cumsum(mesh.hx.min()*np.asarray(nCpad)*2**np.arange(len(nCpad)))


# axs = plt.subplot()
# def inSurface(cell):
#     xyz = cell.center
# #     r, ind = tree.query(x, k=1)

# #     r = np.abs(tri3D.plane_distance(xyz)).min()
    
# #     F = interp2d(xLoc[ind,0], xLoc[ind,1], xLoc[ind,2])
# #     print(xyz, r.min(), ind, tri2D.find_simplex(xyz[:2]))
#     indexTri = tri2D.find_simplex(xyz[:2]) 
#     plt.scatter(xyz[0], xyz[1], c='r')
# #     print(xyz[:2], indexTri)
#     if indexTri != -1:
#         # Compute normal of triangle
# #         tri = tri2D.simplices[indexTri]
#         dZ = F(xyz[:2]) - xyz[2] 
# #         dZ = uNormal[indexTri].dot(xyz) + d[indexTri] - xyz[2]        
# #         print(mesh.hx.min()*2**cell._level*0.5 )

#         for ii, nC in enumerate(nCpad):
        

#             if (dZ < rMax[ii]) :
                
#                 return maxLevel-ii
# #     #         print(dZ, (maxRadius + 5*2**cell._level), dZ < (maxRadius + 5*2**cell._level), dZ > 0)
# #             if (dZ < (maxRadius + 5*2**cell._level)) and (np.abs(dZ) < maxRadius):

# #                 return np.min([cell._level+1, maxLevel])

#     return cell._level

# %time mesh.refine(inSurface)

# # mesh.insert_cells(xLoc, [5]*xLoc.shape[0], finalize=True)

# m = np.zeros((mesh.nC,1))


# r,ind = tree.query(mesh.gridCC)
# r[mesh.gridCC[:,2] > xLoc[0,2]] = 1

# im = mesh.plotSlice(mkvc(r), normal='Z', ind=20, clim=[0,50], ax=axs)




# plt.triplot(xLoc[:,0], xLoc[:,1], tri2D.simplices.copy())




# plt.colorbar(im[0])
# Out:
# Wall time: 15.5 s

# %% [markdown]
# # Try again surface break with invert_cell

# %%
# Same start with mesh and xyz
h = np.ones(64)*5
mesh = Mesh.TreeMesh([h,h,h], )
mesh.x0 = [-100.,-100.,-50.]
# mesh.refine(2, finalize=False)
# mesh.insert_cells(xyz, [3]*xyz.shape[0], finalize=False)
xyz = np.vstack([[0.,100.,53.], [100.,100.,40.], [50.,25.,55.], [0.,-10.,52.]])


expFactor = 2.


octreeLevels = [2, 3]
octreeLevels_XY = [2, 5]

maxLevel = 5

# Compute centroid and largest outer point distance
centroid = np.mean(xyz, axis=0)


rOut = np.linalg.norm(np.r_[
    np.abs(centroid[0]-xyz[:, 0]).min(), 
    np.abs(centroid[1]-xyz[:, 1]).min()
    ]
)

# z = griddata(xyz[:, :2], xyz[:, 2], (mkvc(CCx), mkvc(CCy)), method='linear')

tree = cKDTree(xyz)
# xi = _ndim_coords_from_arrays((gridCC[:,0], gridCC[:,1]), ndim=2)


# Increment the vertical offset
zOffset = 0
depth = 0

# Compute maximum depth of refinement
zmax = np.cumsum(mesh.hz.min()*np.asarray(octreeLevels)*2**np.arange(len(octreeLevels)))
xyMax = np.cumsum(mesh.hx.min()*np.asarray(octreeLevels_XY)*2**np.arange(len(octreeLevels_XY)))
depth = zmax[-1]

plt.subplot()

# Cycle through the Tree levels backward
for ii in range(len(octreeLevels)-1, -1, -1):
    
    dx = mesh.hx.min() * 2**ii
    dy = mesh.hy.min() * 2**ii
    
    expFactor = (rOut + xyMax[ii]) / rOut
    print(expFactor)
    xLoc = (xyz - centroid)*expFactor + centroid

    tri2D = Delaunay(xLoc[:,:2])
    F = sp.interpolate.LinearNDInterpolator(tri2D, xLoc[:,2])
    
    plt.triplot(xLoc[:,0], xLoc[:,1], tri2D.simplices.copy(), c='r')
    limx = np.r_[xLoc[:, 0].max(), xLoc[:, 0].min()]
    limy = np.r_[xLoc[:, 1].max(), xLoc[:, 1].min()]

    # Apply expansion

    nCx = int(np.ceil((limx[0]-limx[1]) / dx))
    nCy = int(np.ceil((limy[0]-limy[1]) / dy))

    dz = mesh.hz.min() * 2**ii

    # Increase the horizontal extent of the surface
    # as a function of Tree level
    # r = ((CCx-midX)**2. + (CCy-midY)**2.)**0.5
    # expFact = (r.max() + 2*mesh.hx.min()*2**ii)/r.max()
    # Create a grid at the octree level in xy
    CCx, CCy = np.meshgrid(
        np.linspace(
            limx[1], limx[0], nCx
            ),
        np.linspace(
            limy[1], limy[0], nCy
            )
    )

    xy = np.c_[CCx.reshape(-1), CCy.reshape(-1)]
    indexTri = tri2D.find_simplex(xy)
    
    z = F(xy[indexTri != -1])
    
    plt.scatter(xy[indexTri != -1, 0],xy[indexTri != -1, 1])
#     dists, indexes = tree.query(np.c_[mkvc(CCx), mkvc(CCy)])

    # Copy original result but mask missing values with NaNs
#     maskRadius = dists < (distMax + depth/padRatio)

    # Only keep points inside the convex hull
#     x, y, z = mkvc(CCx)[maskRadius], mkvc(CCy)[maskRadius], xyz[indexes[maskRadius],2]
    zOffset = 0
    while zOffset < depth:

        mesh.insert_cells(
            np.c_[xy[indexTri != -1], z-zOffset], np.ones_like(z)*maxLevel-ii,
            finalize=False
        )

        zOffset += dz

    depth -= dz * octreeLevels[ii]


mesh.finalize()


m = np.zeros((mesh.nC,1))


r,ind = tree.query(mesh.gridCC)
r[mesh.gridCC[:,2] > xLoc[0,2]] = 1


axs = plt.subplot()
im = mesh.plotSlice(mkvc(r), normal='Z', ind=19, clim=[0,50], ax=axs)

tri2D = Delaunay(xyz[:,:2])
plt.triplot(xyz[:,0], xyz[:,1], tri2D.simplices.copy(), c='b')
plt.scatter(centroid[0], centroid[1], 40, c='r')

plt.colorbar(im[0])

axs.set_xlim([-150,250])
axs.set_ylim([-150,250])
# Out:
# 2.91388533478936
# 1.31898088913156
# (-150, 250)

# %% [markdown]
# # Refine on Surface

# %%
h = np.ones(64)*5
mesh = Mesh.TreeMesh([h,h,h], )
mesh.x0 = [-100.,-100.,-50.]
# mesh.refine(2, finalize=False)
# mesh.insert_cells(xyz, [3]*xyz.shape[0], finalize=False)
xyz = np.vstack([[0.,100.,53.], [100.,100.,40.], [50.,25.,55.], [0.,-10.,52.]])

mesh.insert_cells(xyz, [6]*xLoc.shape[0], finalize=False)

mesh = meshutils.refineTreeXYZ(mesh, xyz, method='surface', octreeLevels=[0, 1, 1],
            octreeLevels_XY=[0, 2, 2],
            finalize=True)

axs = plt.subplot()
im = mesh.plotSlice(np.log10(mesh.vol), normal='Z', ind=21, ax=axs, grid=True)

tri2D = Delaunay(xyz[:,:2])
plt.triplot(xyz[:,0], xyz[:,1], tri2D.simplices.copy(), c='b')
plt.colorbar(im[0])

axs.set_xlim([-150,250])
axs.set_ylim([-150,250])
# Out:
# (-150, 250)

# %%
rOut, xyMax, (rOut + xyMax)/rOut
# Out:
# (45.069390943299865, array([10., 60.]), array([1.22188008, 2.33128047]))

# %%
mesh.gridCC
# Out:
# array([[-80., -80., -30.],
#        [-40., -80., -30.],
#        [-80., -40., -30.],
#        ...,
#        [180., 100., 230.],
#        [100., 180., 230.],
#        [180., 180., 230.]])

# %%
maxLevel = int(np.log2(mesh.hx.shape[0]))
print(maxLevel)

mesh.insert_cells(xLoc, np.r_[maxLevel], finalize=False)

# %%
nCpad=np.r_[1, 1, 1]

stencil = np.r_[
            np.ones(nCpad[0]),
            np.ones(nCpad[1])*2,
            np.ones(nCpad[2])*3
        ]

# Reflect in the opposite direction
vec = np.r_[stencil[::-1],1, stencil]
vecX, vecY, vecZ = np.meshgrid(vec,vec,vec)
gridLevel = np.maximum(np.maximum(vecX,
                       vecY), vecZ)

# Grid the coordinates
vec = np.r_[-stencil[::-1],0, stencil]
vecX, vecY, vecZ = np.meshgrid(vec,vec,vec)
offset = np.c_[mkvc(np.sign(vecX)*2**np.abs(vecX)* mesh.hx.min()),
               mkvc(np.sign(vecY)*2**np.abs(vecY)* mesh.hx.min()),
               mkvc(np.sign(vecZ)*2**np.abs(vecZ)* mesh.hx.min())
              ]

# Replicate the point locations in each offseted grid points
newLoc = np.kron(xLoc, np.ones((offset.shape[0],1))) + np.kron(np.ones((xLoc.shape[0],1)), offset )

mesh.insert_cells(newLoc, mkvc(maxLevel-gridLevel+1))
# vec = vec.reshape((1,vec.shape[0]))

# vec2D = np.kron( vec, np.ones((2,1)) )
# grid = Utils.kron3( vec2D, Utils.speye(vec.shape[1]), Utils.speye(vec.shape[1]))

# %%
np.savetxt('NewLocs.dat', newLoc)

# %%
from scipy.spatial import cKDTree
from scipy import interpolate

def refineTree(
            mesh, xyz,
            finalize=False, dtype="radial",
            octreeLevels=[1, 1, 1],
            octreeLevels_XY=None,
):

    if octreeLevels_XY is not None:

        assert len(octreeLevels_XY) == len(octreeLevels), "Arguments 'octreeLevels' and 'octreeLevels_XY' must be the same length"

    else:

        octreeLevels_XY = np.zeros_like(octreeLevels)

    maxLevel = int(np.log2(mesh.hx.shape[0]))

    tree = cKDTree(xyz)

    if dtype == "radial":

        # Compute the outer limits of each octree level
        rMax = np.cumsum(
            mesh.hx.min() *
            np.asarray(octreeLevels) *
            2**np.arange(len(octreeLevels))
        )

        mesh.insert_cells(xyz, np.ones(xyz.shape[0]) * (maxLevel - np.nonzero(octreeLevels)[0][0] - 1), finalize=False)
        
        def inBall(cell):
            xyz = cell.center
            r, ind = tree.query(xyz)

            for ii, nC in enumerate(octreeLevels):

                if r < rMax[ii]:

                    return maxLevel-ii

            return 0

        mesh.refine(inBall, finalize=finalize)

    elif dtype == 'surface':

        # Compute centroid and
        centroid = np.mean(xyz, axis=0)

        if mesh.dim == 2:
            rOut = np.abs(centroid[0]-xyz).max()
            hz = mesh.hy.min()
        else:
            # Largest outer point distance
            rOut = np.linalg.norm(np.r_[
                np.abs(centroid[0]-xyz[:, 0]).max(),
                np.abs(centroid[1]-xyz[:, 1]).max()
                ]
            )
            hz = mesh.hz.min()

        # Compute maximum depth of refinement
        
        zmax = np.cumsum(
            hz *
            np.asarray(octreeLevels) *
            2**np.arange(len(octreeLevels))
        )
        padWidth = np.cumsum(
            mesh.hx.min() *
            np.asarray(octreeLevels_XY) *
            2**np.arange(len(octreeLevels_XY))
        )

        depth = zmax[-1]

        # Increment the vertical offset
        zOffset = 0
        xyPad = -1
        # Cycle through the Tree levels backward
        for ii in range(len(octreeLevels)-1, -1, -1):

            dx = mesh.hx.min() * 2**ii
            
            
            if mesh.dim == 3:
                dz = mesh.hz.min() * 2**ii
            else:
                dz = mesh.hy.min() * 2**ii

            # Increase the horizontal extent of the surface
            if xyPad != padWidth[ii]:
                xyPad = padWidth[ii]

                # Calculate expansion for padding XY cells
                expFactor = (rOut + xyPad) / rOut
                xLoc = (xyz - centroid)*expFactor + centroid

                if mesh.dim == 3:
                    # Create a new triangulated surface
                    tri2D = Delaunay(xLoc[:, :2])
                    F = interpolate.LinearNDInterpolator(tri2D, xLoc[:, 2])
                else:
                    F = interpolate.interp1d(xLoc[:,0], xLoc[:, 1])

                    
            limx = np.r_[xLoc[:, 0].max(), xLoc[:, 0].min()]
            nCx = int(np.ceil((limx[0]-limx[1]) / dx))
            
            if mesh.dim == 3:
                limy = np.r_[xLoc[:, 1].max(), xLoc[:, 1].min()]
                nCy = int(np.ceil((limy[0]-limy[1]) / dy))

                # Create a grid at the octree level in xy
                CCx, CCy = np.meshgrid(
                    np.linspace(
                        limx[1], limx[0], nCx
                        ),
                    np.linspace(
                        limy[1], limy[0], nCy
                        )
                )

                xy = np.c_[CCx.reshape(-1), CCy.reshape(-1)]

                # Only keep points within triangulation
                indexTri = tri2D.find_simplex(xy)
                
            else:
                xy = np.linspace(
                        limx[1], limx[0], nCx
                        )
                indexTri = np.ones_like(xy, dtype='bool')
                
            z = F(xy[indexTri != -1])

            # Apply vertical padding for current octree level
            zOffset = 0
            while zOffset < depth:

                mesh.insert_cells(
                    np.c_[xy[indexTri != -1], z-zOffset],
                    np.ones_like(z)*maxLevel-ii,
                    finalize=False
                )

                zOffset += dz

            depth -= dz * octreeLevels[ii]

        if finalize:
            mesh.finalize()

    else:
        NotImplementedError("Only dtype= 'surface' | 'points' has been implemented")

    return mesh

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-435b9417d78b> in <module>
# ----> 1 h = np.ones(128)*.1
#       2 mesh = Mesh.TreeMesh([h,h], )
#       3 mesh.x0=[0,-1.5]
#       4
#       5
#
# NameError: name 'np' is not defined

# %%
(np.nonzero(octreeLevels)[0][0])
# Out:
# 0

# %%
# mesh.finalize()


Mesh.TreeMesh.writeUBC(mesh, 'OctreeTest.msh',
                       models={'Actv.mod': np.ones(mesh.nC)})
